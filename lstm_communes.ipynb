# %% [markdown]
# ### Using a neural network to generate French commune names
#
# Original notebook:
# https://github.com/fchollet/keras/blob/master/examples/lstm_text_generation.py
#
# Data source:
# https://www.insee.fr/fr/information/2114819

# %%
import pandas as pd
import numpy as np
from IPython.display import HTML

from __future__ import print_function
import keras
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM, RNN, SimpleRNNCell, SimpleRNN
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import random
import sys
import io

# %%
communes = pd.read_csv('communes.txt', header=None, encoding='latin')
communes.head()

names = communes[0].values
text = '\n'.join(names)

chars = sorted(list(set(text)))
print('total chars: {}'.format(len(chars)))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 76

# %%
print('Corpus length:', len(text), 'lines:', len(names))
print('First 10 lines:', names[:10])
print('Number of unique chars:', len(chars))
# Out:
# Corpus length: 457275 lines: 35885
# First 10 lines: ["L'Abergement-Clémenciat" "L'Abergement-de-Varey" 'Ambérieu-en-Bugey'
#  'Ambérieux-en-Dombes' 'Ambléon' 'Ambronay' 'Ambutrix' 'Andert-et-Condon'
#  'Anglefort' 'Apremont']
# Number of unique chars: 76

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 10
step = 3

sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))
print('First 10 sequences and next chars:')
for i in range(10):
    print('[{}]:[{}]'.format(sentences[i], next_chars[i]))
# Out:
# Number of sequences: 152422
# First 10 sequences and next chars:
# [L'Abergeme]:[n]
# [bergement-]:[C]
# [gement-Clé]:[m]
# [ent-Clémen]:[c]
# [-Clémencia]:[t]
# [émenciat
# L]:[']
# [nciat
# L'Ab]:[e]
# [at
# L'Aberg]:[e]
# [L'Abergeme]:[n]
# [bergement-]:[d]

# %%
print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
print('Size of X: {:.2f} MB'.format(X.nbytes/1024/1024))
print('Size of y: {:.2f} MB'.format(y.nbytes/1024/1024))
# Out:
# Vectorization...
# Size of X: 110.47 MB
# Size of y: 11.05 MB

# %%
# ### Initialization
# 
# Now we are ready to create a recurrent model.  Keras contains three types of recurrent layers:
# 
#  * `SimpleRNN`, a fully-connected RNN where the output is fed back to input.
#  * `LSTM`, the Long-Short Term Memory unit layer.
#  * `GRU`, the Gated Recurrent Unit layer.
# 
# See https://keras.io/layers/recurrent/ for more information.

# Number of hidden units to use:
nb_units = 64

model = Sequential()

# Recurrent layers supported: SimpleRNN, LSTM, GRU:
model.add(LSTM(nb_units, input_shape=(maxlen, len(chars))))

# To stack multiple RNN layers, all RNN layers except the last one need
# to have "return_sequences=True".  An example of using two RNN layers:
#model.add(SimpleRNN(16,
#                    input_shape=(maxlen, len(chars)),
#                    return_sequences=True))
#model.add(SimpleRNN(32))

model.add(Dense(units=len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer)

print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 64)                36096
# _________________________________________________________________
# dense_2 (Dense)              (None, 76)                4940
# _________________________________________________________________
# activation_1 (Activation)    (None, 76)                0
# =================================================================
# Total params: 41,036
# Trainable params: 41,036
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
class SampleResult(keras.callbacks.Callback):

    def on_epoch_end(self, epoch, logs={}):

        start_index = random.randint(0, len(text) - maxlen - 1)

        for diversity in [0.2, 0.5, 1.0, 1.2]:
            generated = ''
            sentence = text[start_index: start_index + maxlen]
            generated += sentence
            print()
            print('----- Generating with diversity',
                  diversity, 'seed: "' + sentence + '"')
            sys.stdout.write(generated)

            for i in range(100):
                x = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(sentence):
                    x[0, t, char_indices[char]] = 1.

                preds = self.model.predict(x, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]

                generated += next_char
                sentence = sentence[1:] + next_char

                sys.stdout.write(next_char)
                sys.stdout.flush()
        print('\n\n')
sample_callback = SampleResult()

# %%
history = model.fit(X, y, 
                        epochs=50, 
                        batch_size=512,
                        verbose=2,
                       callbacks=[sample_callback])
# Out:
# Epoch 1/50
#  - 7s - loss: 1.5728
#
# ----- Generating with diversity 0.2 seed: "snes-les-A"
# snes-les-Amens
# Le Chapelle
# Champagne
# Chanans
# Charon
# Charennes
# Charney-le-Petit
# Saint-Priein-de-Charenne
# Saint-
# ----- Generating with diversity 0.5 seed: "snes-les-A"
# snes-les-Ameraulie
# Aubembre
# Aulling
# Auguin
# Auberten
# Anneville-en-Val
# Le Chapelle
# Chamanting
# Valennes
# Fresnes-F
# ----- Generating with diversity 1.0 seed: "snes-les-A"
# snes-les-Ampunet
# Buutoude
# Bunischedeu
# Boulières
# Bouieu
# Boulosseron
# Le Poulic
# Pouronne
# Guranc
# Buzey
# Bureau
# Char
# ----- Generating with diversity 1.2 seed: "snes-les-A"
# snes-les-Andel
# Noèrele-la-Grain
# Noouzaret
# Norval
# Ousysheieu
# Evelou
# Theffas
# Trécaul
# Toncy-en
# Almane
# Aubasclay
# M
#
#
# Epoch 2/50
#  - 7s - loss: 1.5591
#
# ----- Generating with diversity 0.2 seed: "Farébersvi"
# Farébersviller
# Le Pentilles
# Poussay-le-Bois
# Saint-Martin-de-la-Pois
# Saint-Martin-de-Lande
# Saint-Christol
# Saint
# ----- Generating with diversity 0.5 seed: "Farébersvi"
# Farébersviller
# Villers-les-Bérier
# Le Marie-de-Laurousse
# La Halle-la-Petit
# Montgan
# Montreuil-en-Bois
# Saint-Pier
# ----- Generating with diversity 1.0 seed: "Farébersvi"
# Farébersviller
# Mezidos
# Migoy
# Mandoiville-sur-Loir
# Le Moix-Formac
# Breut
# Clarbonnans
# Moussyz-Fontane
# Vauroc-Lava
# ----- Generating with diversity 1.2 seed: "Farébersvi"
# Farébersviller
# Luzanc
# Jaumont-Véchay
# Sosch
# L
# C:\ProgramData\Anaconda64\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# a T-Arnignay-lèz-Saint-Fréifrencourt
# Lemilly
# Les Enzucychiincol
# Éb
#
#
# Epoch 3/50
#  - 7s - loss: 1.5463
#
# ----- Generating with diversity 0.2 seed: "en
# Samadet"
# en
# Samadet
# Sarnes
# Saint-Martin-de-Rivière
# Saint-Germain-en-Brie
# Bourg-sur-Mer
# Saint-Martin-de-Charney
# Saint-Je
# ----- Generating with diversity 0.5 seed: "en
# Samadet"
# en
# Samadet
# Sarnay-le-Grance
# La Velle-Cardaine
# Marcy-sur-Arbe
# Charbion
# Chizac
# Charmont-les-Bois
# Saint-Martin-de
# ----- Generating with diversity 1.0 seed: "en
# Samadet"
# en
# Samadet
# Serlevier
# Saint-Crémont-sur-Cher
# Vermichier
# Siennes
# Siches
# Soyoyer
# Rermonqueville
# Saint-Aubin-le-Ch
# ----- Generating with diversity 1.2 seed: "en
# Samadet"
# en
# Samadet
# Sacaluyel
# Villels
# Vizevat-Téréond
# Lenjouzot
# Jubrac
# Jampagnec
# Stégouze
# Vientiouss
# Brécofes
# Bray-en-
#
#
# Epoch 4/50
#  - 7s - loss: 1.5358
#
# ----- Generating with diversity 0.2 seed: "ourt
# Macog"
# ourt
# Macoge
# Marey
# Marsac
# Marches
# Marchare
# Marches
# Marches
# Marches-de-Lande
# Saint-Martin-de-Carbert
# Saint-Marti
# ----- Generating with diversity 0.5 seed: "ourt
# Macog"
# ourt
# Macoge
# Morval-sur-Cher
# Saint-Beaut-et-Grand
# Saint-Germain-en-Bierre
# La Brison
# Bussey
# Bures
# Bertences
# Berc
# ----- Generating with diversity 1.0 seed: "ourt
# Macog"
# ourt
# Macoge
# Mouvillard
# Saumont-Prifan
# Saint-Lémy
# Saint-Étienne-les-Haut
# Gigency
# Genches
# Grysmesnie
# Parpy
# Ormes
# ----- Generating with diversity 1.2 seed: "ourt
# Macog"
# ourt
# Macogambe
# Saint-Délire
# Montrette
# Moigny-Apin
# nieus-la-Valnac
# Taligny
# Val-Scquerottas
# Thévis
# Enchalasse
# Sa
#
#
# Epoch 5/50
#  - 8s - loss: 1.5265
#
# ----- Generating with diversity 0.2 seed: "aint-Maign"
# aint-Maignan
# Saint-Martin-de-Carres
# Saint-André-de-Challon
# Saint-André-de-Chartel
# Saint-André-de-Chautes
# Saint
# ----- Generating with diversity 0.5 seed: "aint-Maign"
# aint-Maignac
# Saint-Martin-d'Ayerans
# Saint-Aubin-de-Carme
# Champserie
# Champain
# Champilly-la-Chapelle
# Saint-Bonne
# ----- Generating with diversity 1.0 seed: "aint-Maign"
# aint-Maignelhe
# Chamon-Pernechaise
# Saint-Sacvert
# Chayeroult
# Chaloux
# Charey
# Champinghep
# Ançois-des-Cardeyrac
# Cas
# ----- Generating with diversity 1.2 seed: "aint-Maign"
# aint-Maignes
# Macormalchet-de-Beaurebail
# Saint-Digisâtex
# quefres
# Tehourt
# Touin
# Thien
# Thuspreville
# Mira
# Meriax
# M
#
#
# Epoch 6/50
#  - 8s - loss: 1.5181
#
# ----- Generating with diversity 0.2 seed: "incy-le-Vi"
# incy-le-Vieux
# Saint-Martin-de-Barde
# Saint-Martin-de-Parche
# Saint-Martin-de-Bourg
# Saint-Martin-de-Cour
# Saint-Ge
# ----- Generating with diversity 0.5 seed: "incy-le-Vi"
# incy-le-Vieux
# Courcourt
# Courreau-sur-Laine
# Rochel
# Romancourt
# Massach
# Maton-la-Tour
# La Chapelle-de-Courmont
# Bou
# ----- Generating with diversity 1.0 seed: "incy-le-Vi"
# incy-le-Vinouies-le-Pelles
# Beazan
# Billy
# Boulévilliers
# Hafpen
# Hahouceney
# Ausige
# Aisset-La Pernes
# Maérachez
# Mine
# ----- Generating with diversity 1.2 seed: "incy-le-Vi"
# incy-le-Vifaux
# Tournay-les-Briès-aux-Rieuvare
# Onthez
# Orges-d'Oille
# Croimany
# Cricheix
# Crouy
# Claisay
# Cols-des-Ba
#
#
# Epoch 7/50
#  - 7s - loss: 1.5105
#
# ----- Generating with diversity 0.2 seed: "ltroff
# Fra"
# ltroff
# Frandes
# Fresnes
# Fresnes
# Fresnes-sur-Mer
# Saint-Germain-de-Château
# Saint-Germain-de-Chartie
# Saint-Pierre-
# ----- Generating with diversity 0.5 seed: "ltroff
# Fra"
# ltroff
# Frandieux
# Fontaines
# Lonac-lès-Prosse
# Saint-Pierre-de-Montaine
# Les Aruchère
# Nancourt
# Neut-Étange
# La Lapp
# ----- Generating with diversity 1.0 seed: "ltroff
# Fra"
# ltroff
# Frandies Fours
# Le Gahaëlle
# Sauvet
# Gongouet-et Pacruche-Ollet-Houque
# Saint-Germain-en-Avervey
# Villains-s
# ----- Generating with diversity 1.2 seed: "ltroff
# Fra"
# ltroff
# Francourl-et-Daubure
# Roiphoruck
# Vfuxerog
# Beneuretry
# Renoule
# Renfaccourbaco
# La Crorbe
# Clury
# Vières-Helle
#
#
# Epoch 8/50
#  - 7s - loss: 1.5034
#
# ----- Generating with diversity 0.2 seed: "Vacon
# Vout"
# Vacon
# Voutert
# Voulsac
# Voulsac
# Voulsac
# Vousseville
# Le Ville-le-Château
# Saint-Martin-de-Landrieux
# La Chapelle-le
# ----- Generating with diversity 0.5 seed: "Vacon
# Vout"
# Vacon
# Voutrefarcourt
# Charenties
# Saint-Jean-de-Montagne
# Saint-Juss
# Saint-Martin-d'Aubert
# Saint-Martin-de-Bourga
# ----- Generating with diversity 1.0 seed: "Vacon
# Vout"
# Vacon
# Voute
# Vergerres-Élesse
# Les Blaches
# Bessais
# Beaulier-le-Bourman
# La Grand-Machames
# Band'sarvali
# Davignes
# D
# ----- Generating with diversity 1.2 seed: "Vacon
# Vout"
# Vacon
# Voutiralbourt
#
# Fûlières
# Grandrihonye
# urvèr
# La Gradaux
# Geuvai
# Gediers-et-Serlhes
# Renagou
# Saint-Joso-de-Cu
#
#
# Epoch 9/50
#  - 7s - loss: 1.4967
#
# ----- Generating with diversity 0.2 seed: "e
# Villenou"
# e
# Villenouver
# Villers-Marcham
# Villers-le-Barce
# Saint-Martin-de-Bourgan
# Le Bourgeau
# Bourg-en-Bois
# Saint-Pierre-
# ----- Generating with diversity 0.5 seed: "e
# Villenou"
# e
# Villenoule
# Dompierville
# Harribeux
# Hauton
# Houtert
# Hombercourt
# Les Arceuve
# Argent
# Aubelle
# Aureugny
# Aubigny
# Aur
# ----- Generating with diversity 1.0 seed: "e
# Villenou"
# e
# Villenourt
# Vielley-sur-Saône
# Aurennesson
# Les Montel
# Mitterserca
# Louercardo
# Schir-Fory
# Cabernoigres
# Ailhach
# M
# ----- Generating with diversity 1.2 seed: "e
# Villenou"
# e
# Villenoule-sur-Pières
# Saincabraière
# Taint
# Lénoncruze
# La Rommere
# Rocurccolliers-Bassadé-Cutilly
# Saugoasie
# Sam
#
#
# Epoch 10/50
#  - 8s - loss: 1.4903
#
# ----- Generating with diversity 0.2 seed: "rensal
# Sai"
# rensal
# Saint-Martin-de-Chaulie
# Saint-Martin-de-Bois
# Saint-Martin-de-Berre
# Saint-Martin-de-Bois
# Saint-Martin-de
# ----- Generating with diversity 0.5 seed: "rensal
# Sai"
# rensal
# Saint-Martin-de-Beuvre
# Saint-Hilaire-la-Péhouer
# Saint-Pierre-des-Landron
# Chastel-Champsault
# Claux
# Court
# ----- Generating with diversity 1.0 seed: "rensal
# Sai"
# rensal
# Saint-Micoer-de-Mort-venges
# Conquierlien
# Pancuos
# Méjat
# Melleillas
# Givras
# Give
# Granville-l'Abbnine
# La T
# ----- Generating with diversity 1.2 seed: "rensal
# Sai"
# rensal
# Saint-Boloud-Mineux-Quémine
# Colaix
# Bottevilla
# Quarderé
# Saint-Médort-det-Chermagnen
# Saint-Sacvel
# Saint-A
#
#
# Epoch 11/50
#  - 8s - loss: 1.4845
#
# ----- Generating with diversity 0.2 seed: "eyrac
# Sior"
# eyrac
# Siorg-lès-Montagne
# Saint-Aubin-de-Bourgan
# La Chapelle-les-Bains
# La Calette-de-Boulin
# Saint-Gervais
# Saint
# ----- Generating with diversity 0.5 seed: "eyrac
# Sior"
# eyrac
# Siorg-la-Pins
# Charon
# Chantin
# Champsonnan
# Saint-Crépin-des-Montre
# Saint-Martin-de-Cormes
# Le Contrieu
# Cord
# ----- Generating with diversity 1.0 seed: "eyrac
# Sior"
# eyrac
# Siorg-Aunimbrieu
# Beltrectude
# Alogry
# Andy
# Augeance
# La Rovane
# Sarragorac
# Norres
# Norancour
# Norray
# Pocqhes
# P
# ----- Generating with diversity 1.2 seed: "eyrac
# Sior"
# eyrac
# Sioriègre
# Sivier
# Soud-de-Collier
# Bouff
# Bresxainville-sur-Lèbe
# Comordtanneclus
# Mayvarna
# Pazey
# Hamisis
# Hab
#
#
# Epoch 12/50
#  - 7s - loss: 1.4797
#
# ----- Generating with diversity 0.2 seed: "e-Riez
# Sai"
# e-Riez
# Saint-André-de-Montagne
# Saint-Auban
# Saint-Martin-de-Cormes
# Saint-Martin-de-Crois
# Saint-Aubin-de-Cros
# Sa
# ----- Generating with diversity 0.5 seed: "e-Riez
# Sai"
# e-Riez
# Saint-Laurent-de-Chartitte
# Chambourt
# Château-Saint-Chamastin
# Champagne
# Saint-Martin-de-Bourge
# Villers-s
# ----- Generating with diversity 1.0 seed: "e-Riez
# Sai"
# e-Riez
# Saint-Jean-Saint-Sulzac
# Saint-Nicolas
# Graudières
# La Maharbe-de-Lavillac
# Chamettine
# Vessier-en-Mont-deur
# ----- Generating with diversity 1.2 seed: "e-Riez
# Sai"
# e-Riez
# Saint-Ézousnon
# Buhy
# Baoly
# favez
# Iswilaller
# Noris-Arbiners
# Pariville
# Perillant
# Langlas
# Luignon
# Ruotac
# Ro
#
#
# Epoch 13/50
#  - 7s - loss: 1.4737
#
# ----- Generating with diversity 0.2 seed: "alant
# Buss"
# alant
# Bussy-sur-Mer
# Cournois
# Cournoy
# Cournet
# Courcey
# Courney
# Courancourt
# Le Merche
# Merricourt
# Le Ville-en-Brie
# ----- Generating with diversity 0.5 seed: "alant
# Buss"
# alant
# Bussy-lès-Vien
# Betzan
# Bellefort
# Château-Champsaumis
# Villemontaine
# Saint-Aubin-de-Ville
# Saint-Pierre-de-R
# ----- Generating with diversity 1.0 seed: "alant
# Buss"
# alant
# Bussy
# Fraillès-le-Fhoudon
# Chanevance
# Châtenal-en-Mésoisen
# Chamnay
# Crissy
# Creimes
# Carpelles
# Charvallon
# Ba
# ----- Generating with diversity 1.2 seed: "alant
# Buss"
# alant
# Bussoy-la-Baon
# Rocéry
# Viazey
# Vixac
# Frédéri
# Grastagou
# Ginac
# La F-igon
# Ruilhac-Bédenet
# Morgy
# Coscauboult
# S
#
#
# Epoch 14/50
#  - 7s - loss: 1.4701
#
# ----- Generating with diversity 0.2 seed: "an
# Baguer-"
# an
# Baguer-la-Chapelle
# Champsans
# Charan
# Chartigny-le-Châtel
# Bernelles
# Bertuil
# Belles
# Bernais-de-Bourg
# Saint-Lau
# ----- Generating with diversity 0.5 seed: "an
# Baguer-"
# an
# Baguer-lès-Boursan
# Vaux
# Valley
# Valley
# Vallerac
# Varennes
# Valairon
# Vaucq
# Vellerault
# Bernay
# Belly
# Berney
# Berne
# ----- Generating with diversity 1.0 seed: "an
# Baguer-"
# an
# Baguer-près-Rich
# Rifsère Saint
# Reman-de-Balierbrufgninh
# Le Merchart
# Le Mey
# Meil
# Maillac
# Mavarles
# Mannay-l'E
# ----- Generating with diversity 1.2 seed: "an
# Baguer-"
# an
# Baguer-sous-eu'vre
# Mevanais
# Rézarier
# Saint-Agat
# Séraquier-les-Val-Selore-Lastagne
# Dôve
# Ettepont
# Estic
# Es
# Fa
#
#
# Epoch 15/50
#  - 7s - loss: 1.4651
#
# ----- Generating with diversity 0.2 seed: "
# Condette
# "
#
# Condette
# Courcelles
# Courtais
# Courcelles
# Courtel
# Cournes
# Courtais
# Courtelles
# Saint-Marcel-d'Auterune
# Saint-Mar
# ----- Generating with diversity 0.5 seed: "
# Condette
# "
#
# Condette
# Courcelles
# Courches-Tourge
# Trévillers
# Livainville
# Rotigny-la-Roime
# Saint-Marcel-d'Autigny
# Saint-Mart
# ----- Generating with diversity 1.0 seed: "
# Condette
# "
#
# Condette
# Condrox-lès-Douvier
# Dochepe
# Helgues
# Plabardry
# Pueyrois
# Grancolles
# Purmas
# Podilaupt
# Gihéville
# Haniles
# ----- Generating with diversity 1.2 seed: "
# Condette
# "
#
# Condette
# Château-Théry-Annech
# Châtelles-Villely-en-Dancoux
# Montoy-Saint-Aubin-Saint-Germain-des-Chaptrey
# Sain
#
#
# Epoch 16/50
#  - 8s - loss: 1.4613
#
# ----- Generating with diversity 0.2 seed: "umont-en-H"
# umont-en-Hample
# Saint-Martin-de-Corbes
# Saint-Martin-de-Cormance
# Soussac
# Soussac
# Soussac
# Soussac
# Soussac
# Soussa
# ----- Generating with diversity 0.5 seed: "umont-en-H"
# umont-en-Houvales
# Pont-Saint-Martial-les-Chaperre
# Couron
# Courtestet
# Braulin-en-Boissieu-les-Bagne
# La Chapelle-
# ----- Generating with diversity 1.0 seed: "umont-en-H"
# umont-en-Halais
# Sainte-Colobbouviers
# Arnolles-les-Neus
# Saint-Geurais-de-Lavours
# Saint-Cérévat
# Bruignelles
# Fres
# ----- Generating with diversity 1.2 seed: "umont-en-H"
# umont-en-Héche
# Volhe
# Sochey-Solby-le-Gran
# Beusttont
# Brssot
# Bresoux
# Froise-Flauvet
# Engny
# Épeiney
# Estoinanvis
# Lo
#
#
# Epoch 17/50
#  - 7s - loss: 1.4575
#
# ----- Generating with diversity 0.2 seed: "uck
# Rossel"
# uck
# Rossel
# Rouvres-les-Bois
# Saint-André-de-Bessande
# Saint-André-de-Belleville
# Bernay
# Bernay
# Bergancourt
# Barnay
# ----- Generating with diversity 0.5 seed: "uck
# Rossel"
# uck
# Rossel
# Romance
# Rouvac
# Roussand
# Ranvilly
# Repillers
# Romanges
# Rotterolles
# Les Chambourt
# Chambon
# Champont
# Cham
# ----- Generating with diversity 1.0 seed: "uck
# Rossel"
# uck
# Rosselares
# Puelo
# Dian
# L'Estrép
# Ertromps
# Étrons
# Éfognis
# Dux
# Ervry
# Thellielmelh
# Buts
# Bères
# Bin-en-Torme
# Tria
# ----- Generating with diversity 1.2 seed: "uck
# Rossel"
# uck
# Rosselle
# Rop
# Rapdège
# Rampolillé
# Silhères-ap-Medin
# Bruhajou
# Bins
# Biang
# Obard-sur-Lys
# Laharmer
# Lamedtheur-Ch
#
#
# Epoch 18/50
#  - 8s - loss: 1.4540
#
# ----- Generating with diversity 0.2 seed: "court
# Fres"
# court
# Fresnay-le-Château
# Aunsou
# Aurenne
# Aurin
# Aurenne
# Aurencourt
# La Roche-Follenay
# Saint-Christophe
# La Chapell
# ----- Generating with diversity 0.5 seed: "court
# Fres"
# court
# Fresnay-sur-Chalaine
# Saint-Martin-de-Champagne
# Chastelou
# Caragarde-le-Grand
# Crouillon
# Chardé
# Chantéault
#
# ----- Generating with diversity 1.0 seed: "court
# Fres"
# court
# Fresausac
# Saint-Audon
# Pacry-le-Baisnat
# Sainte-Refols
# Boureville
# La Chapelle-Réwincq
# Pleiron
# Porvily
# Plai
# ----- Generating with diversity 1.2 seed: "court
# Fres"
# court
# Fresuins
# Gauboy
# Genossan
# Deyanne
# Éhâtanges
# Dinjou
# Es Loix
# Libelom
# Nardère-Heuzon
# Vieix
# Viffignay
# Ruffine
#
#
# Epoch 19/50
#  - 7s - loss: 1.4502
#
# ----- Generating with diversity 0.2 seed: "les-Bains
# "
# les-Bains
# Saint-André-de-Bourg
# Saint-Martin-de-Bourg
# Saint-Martin-de-Cournes
# Saint-Jean-de-Charagne
# Saint-Jean
# ----- Generating with diversity 0.5 seed: "les-Bains
# "
# les-Bains
# Saint-Christophe
# Villers-le-Gueuve
# Saint-Sauveur
# Saint-Paul-et-Champsourg-de-Bussia
# Saint-Amand-le-H
# ----- Generating with diversity 1.0 seed: "les-Bains
# "
# les-Bains
# Aundise-Beaugy
# Bertut
# Broncevelle
# Le Tour
# Loisse
# Seines
# Ségancourt
# Les Contres
# Colminay
# Coriville
# Ch
# ----- Generating with diversity 1.2 seed: "les-Bains
# "
# les-Bains
# Boglres
# Bonny-Colaute
# Champlé
# Chapelle-le-Villempcette
# Chapelle-Courgay
# Saint-Briment
# Lohissemes
# Bès
#
#
# Epoch 20/50
#  - 7s - loss: 1.4481
#
# ----- Generating with diversity 0.2 seed: "
# Dozulé
# Dr"
#
# Dozulé
# Drunay-le-Bouche
# La Boisse
# Bourgac
# Boussac
# Bourg
# Boulon
# Bourg
# Bouchac
# Bourg
# Boulon
# Bourg
# Bouligny
# Bour
# ----- Generating with diversity 0.5 seed: "
# Dozulé
# Dr"
#
# Dozulé
# Drunay
# Fantelles
# Franges
# Frantelles-les-Bois
# Villers-de-Valle
# Saint-Julien-sur-Avre
# Saint-André-de-Fon
# ----- Generating with diversity 1.0 seed: "
# Dozulé
# Dr"
#
# Dozulé
# Druchamps
# Tal
# Tauville-Larbac
# Tal
# La Tairat
# Le Trassac-Ricourton
# Rupy
# Jumelancy
# Fonassefirq
# Essarnes-l
# ----- Generating with diversity 1.2 seed: "
# Dozulé
# Dr"
#
# Dozulé
# Drumudens
# Tantinbonnigne
# Lapy-aux-Barazusy
# Balleval
# Bagons
# Bayas
# Boscvelas
# Bandocit
# Hay-le-Puâtours
# Sa
#
#
# Epoch 21/50
#  - 8s - loss: 1.4444
#
# ----- Generating with diversity 0.2 seed: "-Marquenne"
# -Marquennes
# Saint-Pierre-de-Vallon
# Saint-Germain-sur-Charente
# Saint-Pierre-de-Vienne
# Saint-Germain-sur-Mer
# Boi
# ----- Generating with diversity 0.5 seed: "-Marquenne"
# -Marquenne
# Marnes-sur-Autange
# Frandelin
# Le Grand-le-Roc
# Saint-Christophe
# Saint-Pardoux
# Saint-Julien
# Saint-Léon
# ----- Generating with diversity 1.0 seed: "-Marquenne"
# -Marquennes
# La Meulinille
# Fléonte
# Geyreaux
# Genenchon
# Opdrelon
# Ollepille
# Orazignaz
# Norien
# Neusières
# Les Champsa
# ----- Generating with diversity 1.2 seed: "-Marquenne"
# -Marquennes-Toolfaos
# Falle
# Tausiles
# Foriy
# Forges
# Foux
# Frailles
# Grézia
# Le Bourrep
# Butha
# Pains-sur-Meude
# Labranv
#
#
# Epoch 22/50
#  - 7s - loss: 1.4423
#
# ----- Generating with diversity 0.2 seed: "nt-aux-Dam"
# nt-aux-Dame
# Beaucourt-le-Château
# Saint-Martin-de-Bourg-de-Cher
# Saint-Martin-de-Champain
# Saint-Martin-de-Champs
# ----- Generating with diversity 0.5 seed: "nt-aux-Dam"
# nt-aux-Dame
# Bercis
# Bertres
# Beauches-Saint-Martin-du-Fart
# Charline-du-Farton
# Saint-Andé-Lange
# Saint-Martin-de-P
# ----- Generating with diversity 1.0 seed: "nt-aux-Dam"
# nt-aux-Dame
# Ditnac
# Douéon
# Fonge-Lourné
# Saint-Michel-de-Tauis
# Vaux
# Terneux
# Terroval
# Les Chastoriez
# Promey-lès-M
# ----- Generating with diversity 1.2 seed: "nt-aux-Dam"
# nt-aux-Damen
# Varcy-Gédenant-de-Séroster
# Maineux-en-Angence
# Pérage
# Perrart
# Pessinguis
# Tembry
# Taupry
# Troigny
# Tru
#
#
# Epoch 23/50
#  - 7s - loss: 1.4388
#
# ----- Generating with diversity 0.2 seed: "
# Chef-Haut"
#
# Chef-Hautelle
# La Chapelle-du-Barons
# La Barde
# Barnes
# Barnay
# Balannes
# Barans
# Ballenay
# Barennes-Lauteline
# La Cha
# ----- Generating with diversity 0.5 seed: "
# Chef-Haut"
#
# Chef-Haute
# Vaux
# Farentel
# Fauldon
# Tarignac-le-Vivin
# Beaudeville
# Collonnes
# Contens
# Cournes
# Couray
# Courtilly
# Cou
# ----- Generating with diversity 1.0 seed: "
# Chef-Haut"
#
# Chef-Hauteite
# Parlé
# Parguis-d'Aubary
# Coursangods
# Beauvillers
# Lieuvelle-Mirel-sur-Hat
# Mortefort-Millanx
# Biey
# B
# ----- Generating with diversity 1.2 seed: "
# Chef-Haut"
#
# Chef-Hautlierd-Marvire-la-Forêt
# Saint-Ragnan
# Pfsiuis
# Polézeuil
# Siché
# Fardillé-la-Vidier
# Gontanns-Laiveant
# Gan
#
#
# Epoch 24/50
#  - 7s - loss: 1.4359
#
# ----- Generating with diversity 0.2 seed: "amp-le-Duc"
# amp-le-Duc
# Leneuille
# La Chapelle-de-Châteaux
# Saint-Martin-d'Arches
# Saint-Martin-de-Bourg-le-Château
# Saint-Mart
# ----- Generating with diversity 0.5 seed: "amp-le-Duc"
# amp-le-Duc
# Dornay
# Douray
# Doujon
# Dommerolles
# Lannac
# Lazeroux
# Landunay-le-Daut
# Saint-Pries-de-Belommant
# Marcilly
# ----- Generating with diversity 1.0 seed: "amp-le-Duc"
# amp-le-Ducher
# Montbontrieu
# La Boufflé-Loutier
# Moretellier
# La Pont-za-Féry
# Saint-Flogen
# Saint-Pavroi
# Neuvaville
# ----- Generating with diversity 1.2 seed: "amp-le-Duc"
# amp-le-Duc
# Dogdroy-le-Hut
# Béchet-en-Puillon
# La Roye
# Rouyzou
# Rouxcourt
# Lois
# Lusdègnac
# Montéoné
# Méssilleroux
# Vil
#
#
# Epoch 25/50
#  - 7s - loss: 1.4345
#
# ----- Generating with diversity 0.2 seed: "Houlette
# L"
# Houlette
# La Charen
# Charten
# Chardies
# Charran
# Château-de-Lagard
# Saint-Martin-de-Carain
# Saint-Pierre-de-Montaine
#
# ----- Generating with diversity 0.5 seed: "Houlette
# L"
# Houlette
# La Challues
# Chamon-sur-l'Ouf
# Marcy-les-Grand
# Villeneuve-sur-Belonne
# Saint-Martin-des-Lachère
# Le Chare
# ----- Generating with diversity 1.0 seed: "Houlette
# L"
# Houlette
# La Lavauzerte-sur-Allingue
# Saint-Cricton
# Guome-de-Sounert-en-Issiou
# La Noges-Aumont
# Saint-Avand-la-Gu
# ----- Generating with diversity 1.2 seed: "Houlette
# L"
# Houlette
# Le Flanges-en-Moriès
# Sainte-Refray
# La Fores-le-Siches
# Lannalard
# Le Bousiger
# Brunges
# Créches
# Pramely
# P
#
#
# Epoch 26/50
#  - 7s - loss: 1.4317
#
# ----- Generating with diversity 0.2 seed: "n-Yvelines"
# n-Yvelines
# Saint-André
# Saint-Martin-de-Cormange
# Saint-Martin-de-Ville
# Saint-Martin-de-Commery
# Saint-Martin-de-
# ----- Generating with diversity 0.5 seed: "n-Yvelines"
# n-Yvelines
# Saint-André
# Saint-Aubin-du-Sech
# Saint-Martin-du-Bois
# Saint-André-de-Bourg
# Guingeat
# Le Cournes
# Courn
# ----- Generating with diversity 1.0 seed: "n-Yvelines"
# n-Yvelines
# Praisencelle
# Aintiers
# Anten
# Locaride-Biré
# La Grandbeuille
# Andourt
# Auvré
# Auganville
# Habey-et-Torquan
# ----- Generating with diversity 1.2 seed: "n-Yvelines"
# n-Yvelines
# Pons
# Holergues-Eruan-sur-Martse
# Aunerges
# Autun
# Aviaqueff
# Vénoule
# Sevelemmes
# Saint-Sébace
# Megnia-Ciz
#
#
# Epoch 27/50
#  - 8s - loss: 1.4285
#
# ----- Generating with diversity 0.2 seed: "e
# La Goula"
# e
# La Goulain-sur-Seille
# Armeuil-sur-Mer
# Saint-Georges-de-la-Forters
# Saint-Martin-de-Beaumain
# Saint-Martin-de-C
# ----- Generating with diversity 0.5 seed: "e
# La Goula"
# e
# La Goulaimbon
# Warmont
# Warssan
# Wacquers
# Wary-la-Chapelle
# Perrigneux
# Le Pin
# Pray-Chalaine
# Le Thieu
# Les Losses
#
# ----- Generating with diversity 1.0 seed: "e
# La Goula"
# e
# La Goulaye
# Foussé
# Gomivéles-lès-Belle
# Villeflafotte
# Le Fores
# Fouheillem
# Norrefont
# Montép
# Montlestatt
# Rois-le
# ----- Generating with diversity 1.2 seed: "e
# La Goula"
# e
# La Goulantte
# Saint-Hileive-sous-Pronville
# Devigneu
# Dabache
# Dourroux
# Foygonte
# Saint-Pandal
# Nelles
# Le Brenie
# N
#
#
# Epoch 28/50
#  - 7s - loss: 1.4272
#
# ----- Generating with diversity 0.2 seed: "Lignières-"
# Lignières-sur-Mer
# Saint-Martin-de-Bourg-en-Bois
# Saint-Georges-de-Bourg
# Saint-Martin-de-Bourg-en-Bois
# Saint-Mar
# ----- Generating with diversity 0.5 seed: "Lignières-"
# Lignières-sur-Ourche
# Bouchain-Bourge
# Saint-Laurent-de-Mons
# Saint-Germain-sur-Mer
# Gendinan
# Glanges-les-Montaine
# ----- Generating with diversity 1.0 seed: "Lignières-"
# Lignières-villière
# Chémefaille
# Yzon
# Chys
# Juze
# Villegertuil
# Gomberbaint
# Fondey
# Fon
# Foutette-Haute
# Champuis
# Char
# ----- Generating with diversity 1.2 seed: "Lignières-"
# Lignières-am Geyd
# Suzy-Colombers
# Con-Saren
# Coubour-en-Poëlla
# Lavillel
# Kerrdmuchin
# Bisnes
# éfaude
# Aillippen
# Sain
#
#
# Epoch 29/50
#  - 8s - loss: 1.4243
#
# ----- Generating with diversity 0.2 seed: "e-de-Frons"
# e-de-Frons
# Le Cloux
# Conneville
# Bourg-le-Poulie
# Autigny-sur-Seine
# Beauville-le-Château
# Saint-Martin-de-Montagne
# ----- Generating with diversity 0.5 seed: "e-de-Frons"
# e-de-Frons
# Château-du-Bruett
# Montchauville
# Olou
# Ouxon
# Islarde
# Ingloux
# Épernay
# Eyjou
# Lavoure
# Saint-Bonnet-de-Bo
# ----- Generating with diversity 1.0 seed: "e-de-Frons"
# e-de-Frons
# Pess
# Piesses
# Pontry-le-Touche
# Saint-Venders-sur-Aube
# Les Bègnes
# Clenville
# Crosseville
# Étieson
# Estri
# ----- Generating with diversity 1.2 seed: "e-de-Frons"
# e-de-Fronsonge
# Thameusca
# Diveal
# Dontroon
# Dorlin
# Étinapchrombé
# Haisantetoux
# Lacruvelse
# Brécay-Bolleville
# Labané
#
#
# Epoch 30/50
#  - 7s - loss: 1.4226
#
# ----- Generating with diversity 0.2 seed: "n-Terressu"
# n-Terressue
# Trémont
# Trémes
# Trémerille
# Saint-Martin-de-Chames
# Saint-Sauveur
# Saint-Martin-de-Bourgange
# Bourg-en-
# ----- Generating with diversity 0.5 seed: "n-Terressu"
# n-Terressu
# Le Verneux-lès-Courtaise
# Courcey
# Courcelles
# Villes-Bellemont
# Brisses
# Breton-sur-Doute
# Saint-Georges
# ----- Generating with diversity 1.0 seed: "n-Terressu"
# n-Terressurs
# Belles-Rimelhac
# Saint-Nic
# Saint-Christophe
# Heribière enleas
# Guans
# Gounavet
# Le Beaure
# Breschels
# Ba
# ----- Generating with diversity 1.2 seed: "n-Terressu"
# n-Terressuères
# Badonmais
# Abboshei
# Butte
# Pouthignon
# Saint-Barmant-les-Cyssabre
# Sothaignel
# Mans-Boissocier
# Monil
#
#
# Epoch 31/50
#  - 7s - loss: 1.4214
#
# ----- Generating with diversity 0.2 seed: "eville-les"
# eville-les-Bois
# Saint-Martin-de-Chartine
# Saint-Martin-de-Chartin
# Saint-Martin-de-Franche
# Saint-Jean-de-Chartie
# ----- Generating with diversity 0.5 seed: "eville-les"
# eville-les-Haut
# Villers-sur-Marnan
# Terres
# Thilly
# Tiévillers
# Brigny
# Brouillers
# Les Crus
# Les Castel
# Carbériou
# Ca
# ----- Generating with diversity 1.0 seed: "eville-les"
# eville-les-Ipe
# Saint-Martin-di-Bournevais
# Dammac
# Dhangou
# Doyer
# Dienmori
# Dimbougin
# Haugeut
# Hautevillers
# La Land
# ----- Generating with diversity 1.2 seed: "eville-les"
# eville-les-Bains-les-Diinbernoi-les-Perquie
# Giencheville
# Hermicélain
# Edois
# Dide
# Dougeloute
# Le Châtpelois
# Clemm
#
#
# Epoch 32/50
#  - 7s - loss: 1.4187
#
# ----- Generating with diversity 0.2 seed: "omot
# Collo"
# omot
# Collons
# Courcelon
# Courcelles
# Cources
# Cuissy-lès-Montagnes
# Montagne
# Montreuil-sur-Mer
# Saint-Martin-de-Carr
# ----- Generating with diversity 0.5 seed: "omot
# Collo"
# omot
# Collonde
# Corbancourt
# Villeneuve-Mareux
# Le Mailliers
# Marçois
# Marchamps-de-Courcherville
# Perres
# Pierrecourt
# ----- Generating with diversity 1.0 seed: "omot
# Collo"
# omot
# Collonnieux
# Sainte-Cérais
# Vieux-Bassethains
# Pecreson
# Petray
# Heuthet-en
# Vare
# Le Villon
# Volons-lès-Sella-Th
# ----- Generating with diversity 1.2 seed: "omot
# Collo"
# omot
# Collorgue
# Gioixes
# Gbengues-sur-Écullon
# Mossson-ère-Seitiève
# Magny-eil-Corpais-sur-Shillac
# Franges
# d'Ecque
#
#
# Epoch 33/50
#  - 7s - loss: 1.4167
#
# ----- Generating with diversity 0.2 seed: "ard-en-Bea"
# ard-en-Beauvesne-la-Barde
# Saint-Martin-de-Bourg-de-la-Montagne
# La Chapelle-des-Lande
# Saint-Martin-de-Cassenac
#
# ----- Generating with diversity 0.5 seed: "ard-en-Bea"
# ard-en-Beauvale
# La Chapelle-Saint-Croix-du-Nies
# entette-sur-Marne
# Argent
# Arnhanc
# Averle
# Bargen
# Bassy-Saint-Par
# ----- Generating with diversity 1.0 seed: "ard-en-Bea"
# ard-en-Beaucin
# Issy-le-Lich
# Mourières
# Puygney-la-Géry
# Flanges
# Gassèvel
# Gilleman
# Grossière-Jnac
# Évilly-en-Laren
# ----- Generating with diversity 1.2 seed: "ard-en-Bea"
# ard-en-Beaz
# Loverles-Saint-Mariez
# Mozay-Valpalhy-dt-Nûlé
# Beauchhor-Marbéville
# Avezoucy
# Bassy
# Aandon
# Malen
# Sain
#
#
# Epoch 34/50
#  - 7s - loss: 1.4160
#
# ----- Generating with diversity 0.2 seed: "rd
# Carbay
# "
# rd
# Carbay
# Cantelles
# Chasserolles
# Marches
# Marches-sur-Marne
# La Chapelle-de-Caret
# La Chapelle-de-Caret
# La Chapel
# ----- Generating with diversity 0.5 seed: "rd
# Carbay
# "
# rd
# Carbay
# Campagne-Fontaine
# Maulcheix
# Marine
# Mariches
# Marchemant
# Crissat
# Cuzey
# Campagne-le-Vivière
# Jamps-en-Be
# ----- Generating with diversity 1.0 seed: "rd
# Carbay
# "
# rd
# Carbay
# Cagnac-Lara-du-Cuch
# Sainte-Blimenge
# Crieux
# Craglon
# Creuvre
# Cussein-en-Darnou
# Saint-Sulvix
# Saint-Pier
# ----- Generating with diversity 1.2 seed: "rd
# Carbay
# "
# rd
# Carbay
# Bardège
# Anbert-Rovèvr
# Kignies
# Flatenéez
# Luycruet-de-Chès
# Seiller
# Sin-Lullière
# Langdres
# La Capeau
# Cêt
#
#
# Epoch 35/50
#  - 7s - loss: 1.4142
#
# ----- Generating with diversity 0.2 seed: "nt-Hélier
# "
# nt-Hélier
# Saint-Martin-de-Cartine
# Le Mesnil-Champagne
# Champagne-les-Chapont
# Montbart
# Montagny
# Montcilly
# Montch
# ----- Generating with diversity 0.5 seed: "nt-Hélier
# "
# nt-Hélier
# Saint-Pérain-de-Blange
# Saint-Jean-le-Petit
# Noué
# Pourgonne
# Poutard
# Possières
# Pierre
# Pilliers
# Pierres
#
# ----- Generating with diversity 1.0 seed: "nt-Hélier
# "
# nt-Hélier
# Villenès-le-Pierre
# Rivelsouse
# Baslaau
# Baresporders
# Brange
# Boulousout
# La Méalle-la-Voxillie
# Souchères
# ----- Generating with diversity 1.2 seed: "nt-Hélier
# "
# nt-Hélier
# Pénégou
# Merlon
# Reyaux
# Ronchabert
# By-sur-Seine
# Aullevehilea
# Messeaumon
# Parosse
# Pappineu
# Lavesart
# La C
#
#
# Epoch 36/50
#  - 7s - loss: 1.4122
#
# ----- Generating with diversity 0.2 seed: "nac-la-Riv"
# nac-la-Rivière
# Saint-Martin-de-Garde
# Saint-Martin-de-Frans
# Le Croix-le-Château
# Beaucourt
# Bellembreville
# Ortel
#
# ----- Generating with diversity 0.5 seed: "nac-la-Riv"
# nac-la-Rivière
# Plantière
# La Sauvetr
# Saint-Cricq
# Saint-Vincent-sur-Mer
# Bonnes
# Bonneville
# Berreville
# Le Haute
# L'
# ----- Generating with diversity 1.0 seed: "nac-la-Riv"
# nac-la-Rivière
# Frander
# Le Bragne
# Bigay
# Bézac
# Miron
# Monacert
# Mouteries-la-Pomple
# Cormepont
# Condesay
# Courvières
#
# ----- Generating with diversity 1.2 seed: "nac-la-Riv"
# nac-la-Rivièle
# Gentanol
# Frosières
# Flerguay-aux-Balles
# Le Fruet-le-Écolle
# Veudieville
# Lamerpière
# Betzanges-Made
#
#
# Epoch 37/50
#  - 7s - loss: 1.4100
#
# ----- Generating with diversity 0.2 seed: "nt-Clair-s"
# nt-Clair-sur-Seine
# Bourg-le-Bard
# Saint-Martin-de-Bourg-le-Petit
# Saint-Pierre-de-Chers
# Saint-Pierre-de-Chaux
# Sa
# ----- Generating with diversity 0.5 seed: "nt-Clair-s"
# nt-Clair-sur-Loire
# Montelles
# Monterrelle
# Les Auberts
# Barnay
# Barnay
# Barsigny
# Bancourt-sur-Mer
# La Peyenne-le-Boi
# ----- Generating with diversity 1.0 seed: "nt-Clair-s"
# nt-Clair-s-le-Bartron
# La Courne
# Monchallemont
# Lancious
# Saint-Maurice
# Notre-Dame
# Arges-sur-Petin
# Montmon
# Montba
# ----- Generating with diversity 1.2 seed: "nt-Clair-s"
# nt-Clair-sur-Troviers
# Colancetre
# Ossève-de
# Lespignac
# Leshempnat
# Beurquillines
# Lesel-Futse
# Léjunne
# Lémils
# Lille
#
#
# Epoch 38/50
#  - 7s - loss: 1.4089
#
# ----- Generating with diversity 0.2 seed: "queux
# Vill"
# queux
# Villeneuve-le-Château
# Beaucourt
# Beaumont-Fontain-Courbonne
# Courville
# Cournay
# Courcelles
# Courcelles
# Cussy
# ----- Generating with diversity 0.5 seed: "queux
# Vill"
# queux
# Villes
# Verneux
# Verdut
# Vesnes
# Vernel-sur-Couand
# Saint-Marcel-de-Marthe
# Saint-André
# Saint-Martin-d'Arche
# S
# ----- Generating with diversity 1.0 seed: "queux
# Vill"
# queux
# Villevier
# Vieillod
# Vivigny-de-Méarne
# Saint-Nicolas
# L'Angle-Laussonnac
# Pourvières-la-Valvage
# Champpey-Sal
# ----- Generating with diversity 1.2 seed: "queux
# Vill"
# queux
# Villeur
# Vrouilly
# Crény
# Craharcon
# Clasceaumont-Harinard
# Paisnes
# La Beaunier
# Beaupongy
# Chapeyrouse
# Ferragn
#
#
# Epoch 39/50
#  - 7s - loss: 1.4081
#
# ----- Generating with diversity 0.2 seed: "quoy
# Buire"
# quoy
# Buire
# Bures
# Buresse
# Buret
# Bure
# Buret
# Buret
# Bures
# Bures
# Buresse
# Buresse
# Burières
# Bussy-sur-Meuze
# Saint-Jea
# ----- Generating with diversity 0.5 seed: "quoy
# Buire"
# quoy
# Buiremont
# Brissy-de-Carbel
# Saint-Jean-de-Vernes
# Saint-André-en-Brierne
# Montagne
# Montfort-Pont-sur-Eure
# Sa
# ----- Generating with diversity 1.0 seed: "quoy
# Buire"
# quoy
# Buire
# Barfontbonny
# Lo Bouling-Coulin-lès-Oionde
# Monnois
# Méragnon
# Montenast
# Myon-en-Parc
# Madel-de-Jeyrac
# L
# ----- Generating with diversity 1.2 seed: "quoy
# Buire"
# quoy
# Buire
# Buriazin
# Chabedoc-Cononnay
# Sogneilliers
# Rainac
# Resauvilla
# Massiches
# Mals
# Besnières
# Laticourt
# Ragny
#
#
#
# Epoch 40/50
#  - 7s - loss: 1.4067
#
# ----- Generating with diversity 0.2 seed: "ou
# Lauzun
# "
# ou
# Lauzun
# Laverneau
# La BoucheLange
# La Barde-la-Chapelle-les-Bains
# Saint-Martin-de-Chermes
# Le Champenies
# Champi
# ----- Generating with diversity 0.5 seed: "ou
# Lauzun
# "
# ou
# Lauzun
# Landaux
# Landemps
# La Chapelle-de-Longues
# Saint-Christophe-sur-Mer
# Gendenache
# Bouagne
# Bouchenay-le-Pet
# ----- Generating with diversity 1.0 seed: "ou
# Lauzun
# "
# ou
# Lauzun
# Sainte-Eure-du-Laz
# Saint-Symmon
# Saint-Pierre-de-Latnad
# Saint-Pierre-lès-Blezine
# Fomps
# Denhachetil
# Cr
# ----- Generating with diversity 1.2 seed: "ou
# Lauzun
# "
# ou
# Lauzun
# Lécaz
# Rébleuvre-sur-Aupot
# Autinilla
# Ercé
# Uscham
# Lajana
# Quenelle
# Reuzecourt
# Schepcy
# Sellan
# Seneigtign
#
#
# Epoch 41/50
#  - 8s - loss: 1.4051
#
# ----- Generating with diversity 0.2 seed: "Osse
# Larti"
# Osse
# Lartigue
# La Roche-Boisse
# Le Plessis-Saint-Martin-de-Chamesnies
# Saint-Martin-de-Bois
# Saint-Martin-de-Chama
# ----- Generating with diversity 0.5 seed: "Osse
# Larti"
# Osse
# Lartigue
# La Roche-aux-Bois
# Saint-Martin-de-Préchy
# Sainte-Mariele
# Loisselon
# Les Breuillay
# Brieuil-sur-Marn
# ----- Generating with diversity 1.0 seed: "Osse
# Larti"
# Osse
# Lartiers
# Labernelart
# Laviller
# Liek
# Lanville
# Urthier-en-Ines
# Neuville-Merle
# Chambé-sur-Gastard
# Saint-Perma
# ----- Generating with diversity 1.2 seed: "Osse
# Larti"
# Osse
# Lartille
# La Trons
# Sainte-Clan
# Beffuzes
# Basseuil
# Le Pé
# Heidines-Punerix
# Velascoirrat
# Mershuël
# Bellince
# Bré
#
#
# Epoch 42/50
#  - 8s - loss: 1.4042
#
# ----- Generating with diversity 0.2 seed: "s
# Rubrouck"
# s
# Rubrouckire
# Bourget
# Boussac
# Bourg
# Bazines
# Barennes-sur-Marne
# Marcers
# Marcilly
# Méringues
# Montagny
# Montaiguill
# ----- Generating with diversity 0.5 seed: "s
# Rubrouck"
# s
# Rubroucker
# Berneaux
# Beaumont
# Bellebrunac
# Carles
# Campont
# Carmiers-le-Château
# Thitte
# Toucheim-Belles
# Le Mesnil
# ----- Generating with diversity 1.0 seed: "s
# Rubrouck"
# s
# Rubrouckonselheven
# Agessac-en-Caons
# Lourrec
# Loubiez
# Aucurt
# Avillertange
# Bat
# Badeur-Sainte-Colombex
# Montlérof
# ----- Generating with diversity 1.2 seed: "s
# Rubrouck"
# s
# Rubrouckirofre
# Bié
# Bohbrubièx
# Nussey-sur-Oute
# Lagrique
# Lauvres
# Leyranges
# Thuzielles-et-Manceurs
# Saupe
# G'dt-P
#
#
# Epoch 43/50
#  - 8s - loss: 1.4028
#
# ----- Generating with diversity 0.2 seed: "n
# Anduze
# L"
# n
# Anduze
# Langenay
# Langenay
# Landel
# Lantelay
# Landenay
# Langenolles
# La Chapelle-de-Lannech
# Saint-Martin-de-Luche
# S
# ----- Generating with diversity 0.5 seed: "n
# Anduze
# L"
# n
# Anduze
# Les Boschel
# Boulon
# Bourguent
# Bougney
# Boussin
# Brastron
# Broschelles
# La Ville-sur-Loire
# Romalne
# Rouillan
# ----- Generating with diversity 1.0 seed: "n
# Anduze
# L"
# n
# Anduze
# Les Castres-Saillons
# Orezaubit
# Ligny-le-Jouf-Puèvre
# Vizy
# Fréhannes
# Marçais
# Manzec
# Mérasseppard
# Le Noi
# ----- Generating with diversity 1.2 seed: "n
# Anduze
# L"
# n
# Anduze
# Labartillat
# Petrac
# Pinéville-Bézey-Moringet
# Volloule
# Viblainve
# Trittefciville
# Yvelle
# Egueval
# Eschiey
#
#
#
# Epoch 44/50
#  - 8s - loss: 1.4015
#
# ----- Generating with diversity 0.2 seed: "émy-de-Sil"
# émy-de-Sillans
# Dranne
# Durmant
# Duren
# Dompierre-le-Château
# Beaumont-la-Pote
# Saint-Martin-de-Prinay
# Saint-Martin-
# ----- Generating with diversity 0.5 seed: "émy-de-Sil"
# émy-de-Silhy
# Saumy
# Saint-Sulpice-sur-Loire
# Saint-Romain-de-Bourg-le-Comte
# Montausoux
# Saint-Aubin-de-Vieux
# Sain
# ----- Generating with diversity 1.0 seed: "émy-de-Sil"
# émy-de-Sillenoul
# Champrichy-Mez
# Piné-Couraisy-lès-Molan
# Montolin
# Mont-Sainte-Marie
# Bréville
# Clolécourt
# Lonvill
# ----- Generating with diversity 1.2 seed: "émy-de-Sil"
# émy-de-Silhac-Himnay
# Valmont
# Taliat
# Tézuy
# Trasnive
# Vécasse-Montarre
# Vy-sous-Crahac
# Saint
# Serrec
# Sellannghe
# Eyg
#
#
# Epoch 45/50
#  - 8s - loss: 1.4005
#
# ----- Generating with diversity 0.2 seed: "s
# Issendol"
# s
# Issendol
# Josse
# Villers-les-Baillon
# La Chapelle-Saint-Julien-de-Chaude
# Saint-Joisen-de-Bourse
# Le Bourg
# Bouche
# ----- Generating with diversity 0.5 seed: "s
# Issendol"
# s
# Issendol
# Jamps
# Rivières
# Rébeville
# Riccourt
# Rebourg
# Rantage
# Randeville-la-Forêt
# Châtenourt
# Chartey
# Champson
# S
# ----- Generating with diversity 1.0 seed: "s
# Issendol"
# s
# Issendol
# Joizé
# Terneres
# Le Bectervilly
# enge
# Utrrempse
# Vernancourt-sur-Verrord
# Puats
# Gernoront
# Guindéville-sc
# ----- Generating with diversity 1.2 seed: "s
# Issendol"
# s
# Issendol
# Issin
# Igurcy
# Izilles-le-Potieu
# Valbonthagnan
# Montrecq
# Rigeand-Blolies
# Sainten
# Roimas
# Runville-sur-C
#
#
# Epoch 46/50
#  - 8s - loss: 1.3981
#
# ----- Generating with diversity 0.2 seed: "vremoine
# S"
# vremoine
# Saint-André-en-Brie
# Saint-André-en-Brie
# Le Mesnil-Bessier
# Saint-Jean-de-la-Villa
# Champs-en-Beau
# Saint
# ----- Generating with diversity 0.5 seed: "vremoine
# S"
# vremoine
# Saint-Germain-d'Argens
# Saint-Sauveur
# Courcourt
# Courgon
# Coursancourt
# Villeneuve-de-Lucherol
# Montbers
# M
# ----- Generating with diversity 1.0 seed: "vremoine
# S"
# vremoine
# Sainte-en
# SZentas
# Fasseno
# Favignies
# Fulles
# Gersot
# Germon-les-Lages
# Castel
# Camals
# Cagneva
# Caason
# Cafay
# ----- Generating with diversity 1.2 seed: "vremoine
# S"
# vremoine
# Sattigny-Limy
# Lim
# fllus
# Loc
# Anca
# Navers
# Langé-voye
# Botal
# Bougcé
# Braux
# Brieux
# Le Tirouagin
# Tarzé-le-Do
#
#
# Epoch 47/50
#  - 8s - loss: 1.3989
#
# ----- Generating with diversity 0.2 seed: "ur-Mer
# Cou"
# ur-Mer
# Cournette
# Courtene
# Courcelle
# Courcelles-le-Vieux
# Saint-Martin-de-Luze
# Saint-Martin-de-Marcie
# Le Merlier
# ----- Generating with diversity 0.5 seed: "ur-Mer
# Cou"
# ur-Mer
# Courcourt
# Courcelles-sur-Loire
# Maulgny-la-Bard
# Beaurecourt
# Fournay
# Fournay-la-Roc
# Saint-Pierre-sur-Vino
# ----- Generating with diversity 1.0 seed: "ur-Mer
# Cou"
# ur-Mer
# Couteruvilliers
# Thieuren
# Tecciencez
# Neufflo
# Plyise
# Pourbaus
# Poulme-d'Houzet
# Le Marthe-lès-Bruis
# Courign
# ----- Generating with diversity 1.2 seed: "ur-Mer
# Cou"
# ur-Mer
# Cours
# Crunhuville
# Frelleuil
# Le Véat-Fillas
# Frosseux
# Debivesniz
# Wrbussain
# Harneux
# Dergaints
# DinDieu
# Domm
#
#
# Epoch 48/50
#  - 8s - loss: 1.3984
#
# ----- Generating with diversity 0.2 seed: "-en-Septai"
# -en-Septaine
# Saint-Martin-de-Cher
# Crouilly
# Cressin
# Crossey
# Cromignac
# Courcelles
# Courten
# Courgan
# Cournay
# Courte
# ----- Generating with diversity 0.5 seed: "-en-Septai"
# -en-Septaine
# La Chapelle-Rieux
# Saint-Martin-du-Bardon
# Saint-Aubin-de-Landance
# La Chapelle-Saint-Ilmage
# Saint-P
# ----- Generating with diversity 1.0 seed: "-en-Septai"
# -en-Septaine
# Dizac
# Dressac
# Destreviel
# Villeyr-Évre
# Laderfane-en-Vignac
# Maillands
# Marigny-sous-Crés
# Fourdeville
# ----- Generating with diversity 1.2 seed: "-en-Septai"
# -en-Septaid
# Sainte-Cylorel
# Cranay-lès-Blenay
# Villier-Villariville
# Haizéhon Lougst
# Mougon
# Mouardonv-ser-Lourail
#
#
# Epoch 49/50
#  - 8s - loss: 1.3952
#
# ----- Generating with diversity 0.2 seed: "e
# Saint-Ma"
# e
# Saint-Marcel
# Saint-Martin-de-Chamas
# Saint-Jean-de-Courchamp
# Cournecourt
# Les Longue
# La Neuvale-en-Beauce
# La d
# ----- Generating with diversity 0.5 seed: "e
# Saint-Ma"
# e
# Saint-Marcel
# Saint-Germain-sur-Coyeule
# Le Marbers
# Marches
# Manches
# Maches-lès-Étresnières
# Les Louge
# Longuevil
# ----- Generating with diversity 1.0 seed: "e
# Saint-Ma"
# e
# Saint-Marcel
# Saint-Paixh
# Allavre-lès-Villac
# Mullizeas
# Louézac
# Lods
# Attuin
# Lons-la-Valle
# Mardiac
# Manaf-de-Cor
# ----- Generating with diversity 1.2 seed: "e
# Saint-Ma"
# e
# Saint-Maurice-le-Pentaix
# tesen-la-Palle
# Vaci-Lampont
# Villonge-Morand
# Saint-Chésal
# Labestiaud
# Réchelin
# Ridon
#
#
#
# Epoch 50/50
#  - 8s - loss: 1.3956
#
# ----- Generating with diversity 0.2 seed: "y
# Bassenev"
# y
# Bassenevaude
# La Chapelle-Saint-Amand-le-Grande
# Montmaroux
# Montreuil-le-Château
# Saint-Martin-de-Bourg-le-Peti
# ----- Generating with diversity 0.5 seed: "y
# Bassenev"
# y
# Basseneville
# Reins
# Risois-les-Porbaux
# Benay
# Beauval-Saint-Germain-de-Prétiez
# Le Mardier-Sainte-Marie-d'Aurba
# ----- Generating with diversity 1.0 seed: "y
# Bassenev"
# y
# Basseneville
# Taillie
# Trabron
# Eisan
# Eshernes
# Estéguen
# Essaisné
# Fléonay-sur-Arbret
# Béchant
# Bellefondaise
# Ville
# ----- Generating with diversity 1.2 seed: "y
# Bassenev"
# y
# Basseneve
# Warquier-le-Prigu
# Centescac
# Lelouss
# Rasolsas-Eaux-Beaumot
# Château-d'Auché
# Vecombierguet
# Moissand
# M
